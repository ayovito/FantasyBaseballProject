# %% [markdown]
# Knowing that we're dealing with small sample sizes from some of our breakout candidates, let's now look at their batted ball profile to get a sense of if they got lucky by landing into the breakout category or if their plate discipline suggests that their inclusion was not a fluke.

# %%
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None
# %matplotlib inline
pd.set_option("display.max_rows",500)

# %%
# I finally realized the ability to create custom datasets so I created one with batted ball and plate discipline statistics
batted_ball_plate_disc_2015 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/batted_ball_plate_discipline_2015.csv")
batted_ball_plate_disc_2016 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/batted_ball_plate_discipline_2015.csv")
batted_ball_plate_disc_2017 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/batted_ball_plate_discipline_2015.csv")

# %%
# import merged data to merge again with new batted_ball data
merged_2015 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/merged_2015.csv", index_col=0)
merged_2016 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/merged_2016.csv", index_col=0)
merged_2017 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/merged_2017.csv", index_col=0)

# %%
# let's see what we're working with
batted_ball_plate_disc_2017.head()
# Out:
#                Name          Team  GB/FB     LD%     GB%     FB%   HR/FB  \
# 0      Bryce Harper     Nationals   0.98  22.2 %  38.5 %  39.3 %  27.3 %
# 1        Joey Votto          Reds   1.28  25.0 %  42.2 %  32.8 %  21.6 %
# 2      Corey Seager       Dodgers   2.00  20.3 %  53.2 %  26.6 %  19.0 %
# 3  Paul Goldschmidt  Diamondbacks   1.19  23.4 %  41.6 %  35.0 %  22.3 %
# 4        Mike Trout        Angels   0.97  24.4 %  37.2 %  38.4 %  25.3 %
#
#   O-Swing% Z-Swing%  Swing% O-Contact% Z-Contact% Contact%   Zone% F-Strike%  \
# 0   27.6 %   72.5 %  44.7 %     60.9 %     84.4 %   75.4 %  38.0 %    54.6 %
# 1   19.1 %   62.0 %  37.3 %     70.9 %     82.5 %   79.1 %  42.4 %    54.5 %
# 2   29.3 %   77.2 %  51.0 %     56.2 %     88.1 %   78.0 %  45.3 %    62.8 %
# 3   22.4 %   61.6 %  39.4 %     67.5 %     82.5 %   77.7 %  43.4 %    54.2 %
# 4   24.4 %   55.6 %  38.1 %     66.3 %     87.7 %   80.0 %  44.0 %    56.7 %
#
#    SwStr%   Pull%   Cent%   Oppo%  playerid
# ...

# %%
# rename Name to Player_Name for correct merging
batted_ball_plate_disc_2015.rename(columns={'Name':'Player_Name'}, inplace=True)
batted_ball_plate_disc_2016.rename(columns={'Name':'Player_Name'}, inplace=True)
batted_ball_plate_disc_2017.rename(columns={'Name':'Player_Name'}, inplace=True)

# %%
merged_2017.head()
# Out:
#      Player_Name   PA   AB  Hits    R  HR  RBI  SB     BA    xBA    OBP  \
# 0     A.J. Ellis  163  143    30   17   6   14   0  0.210  0.197  0.298
# 1   A.J. Pollock  466  425   113   73  14   49  20  0.266  0.265  0.330
# 2  Aaron Altherr  412  372   101   58  19   65   5  0.272  0.244  0.340
# 3    Aaron Hicks  361  301    80   54  15   52  10  0.266  0.233  0.372
# 4    Aaron Judge  678  542   154  128  52  114   9  0.284  0.278  0.422
#
#    BABIP  BABIP.1    ISO  ISO.1    SLG  SLG.1   wOBA  wOBA.1  xwOBA  BB/PA  \
# 0  0.222    0.222  0.161  0.161  0.371  0.371  0.294   0.294  0.273  0.074
# 1  0.291    0.291  0.205  0.205  0.471  0.471  0.340   0.347  0.331  0.075
# 2  0.328    0.328  0.245  0.245  0.516  0.516  0.359   0.367  0.330  0.078
# 3  0.290    0.290  0.209  0.209  0.475  0.475  0.363   0.367  0.335  0.141
# 4  0.357    0.357  0.343  0.343  0.627  0.627  0.430   0.441  0.446  0.187
#
#     K/PA  Launch_Speed  Launch_Angle  Whiffs  Swings  Takes  wRC+  WAR  \
# ...

# %%
# set index to 'playerid'
merged_2015.set_index('playerid', drop=True)
merged_2016.set_index('playerid', drop=True)
merged_2017.set_index('playerid', drop=True)
batted_ball_plate_disc_2015.set_index('playerid', drop=True)
batted_ball_plate_disc_2016.set_index('playerid', drop=True)
batted_ball_plate_disc_2017.set_index('playerid', drop=True)
# Out:
#                     Player_Name          Team  GB/FB     LD%     GB%     FB%  \
# playerid
# 11579              Bryce Harper     Nationals   0.98  22.2 %  38.5 %  39.3 %
# 4314                 Joey Votto          Reds   1.28  25.0 %  42.2 %  32.8 %
# 13624              Corey Seager       Dodgers   2.00  20.3 %  53.2 %  26.6 %
# 9218           Paul Goldschmidt  Diamondbacks   1.19  23.4 %  41.6 %  35.0 %
# 10155                Mike Trout        Angels   0.97  24.4 %  37.2 %  38.4 %
# 1744             Miguel Cabrera        Tigers   1.29  25.2 %  42.1 %  32.7 %
# 13130             Mikie Mahtook          Rays   0.75  23.3 %  32.9 %  43.8 %
# 3255         Franklin Gutierrez      Mariners   1.14  23.7 %  40.7 %  35.6 %
# 5038             Josh Donaldson     Blue Jays   1.18  17.3 %  44.8 %  37.9 %
# 2218                Ryan Raburn       Indians   1.27  21.5 %  43.8 %  34.6 %
# 2434                Nelson Cruz      Mariners   1.34  20.4 %  45.7 %  34.0 %
# ...

# %%
batted_ball_plate_disc_2017.head()
# Out:
#         Player_Name          Team  GB/FB     LD%     GB%     FB%   HR/FB  \
# 0      Bryce Harper     Nationals   0.98  22.2 %  38.5 %  39.3 %  27.3 %
# 1        Joey Votto          Reds   1.28  25.0 %  42.2 %  32.8 %  21.6 %
# 2      Corey Seager       Dodgers   2.00  20.3 %  53.2 %  26.6 %  19.0 %
# 3  Paul Goldschmidt  Diamondbacks   1.19  23.4 %  41.6 %  35.0 %  22.3 %
# 4        Mike Trout        Angels   0.97  24.4 %  37.2 %  38.4 %  25.3 %
#
#   O-Swing% Z-Swing%  Swing% O-Contact% Z-Contact% Contact%   Zone% F-Strike%  \
# 0   27.6 %   72.5 %  44.7 %     60.9 %     84.4 %   75.4 %  38.0 %    54.6 %
# 1   19.1 %   62.0 %  37.3 %     70.9 %     82.5 %   79.1 %  42.4 %    54.5 %
# 2   29.3 %   77.2 %  51.0 %     56.2 %     88.1 %   78.0 %  45.3 %    62.8 %
# 3   22.4 %   61.6 %  39.4 %     67.5 %     82.5 %   77.7 %  43.4 %    54.2 %
# 4   24.4 %   55.6 %  38.1 %     66.3 %     87.7 %   80.0 %  44.0 %    56.7 %
#
#    SwStr%   Pull%   Cent%   Oppo%  playerid
# ...

# %%
# merge both datasets on 'playerid' index (should have done this before...)
merged_2015_v2 = pd.merge(merged_2015, batted_ball_plate_disc_2015, left_index=True, right_index=True)
merged_2016_v2 = pd.merge(merged_2016, batted_ball_plate_disc_2016, left_index=True, right_index=True)
merged_2017_v2 = pd.merge(merged_2017, batted_ball_plate_disc_2017, left_index=True, right_index=True)

# %%
# look at merged dataset
merged_2017_v2
# Out:
#             Player_Name_x   PA   AB  Hits    R  HR  RBI  SB     BA    xBA  \
# 0              A.J. Ellis  163  143    30   17   6   14   0  0.210  0.197
# 1            A.J. Pollock  466  425   113   73  14   49  20  0.266  0.265
# 2           Aaron Altherr  412  372   101   58  19   65   5  0.272  0.244
# 3             Aaron Hicks  361  301    80   54  15   52  10  0.266  0.233
# 4             Aaron Judge  678  542   154  128  52  114   9  0.284  0.278
# 5         Abraham Almonte  195  172    40   26   3   14   2  0.233  0.231
# 6             Adam Duvall  647  587   146   78  31   99   5  0.249  0.217
# 7              Adam Eaton  107   91    27   24   2   13   3  0.297  0.228
# 8              Adam Engel  336  301    50   34   6   21   8  0.166  0.164
# 9            Adam Frazier  454  406   112   55   6   53   9  0.276  0.275
# 10             Adam Jones  635  597   170   82  26   73   2  0.285  0.258
# 11              Adam Lind  301  267    81   39  14   59   1  0.303  0.291
# ...

# %%
merged_2017_v2.count()
# Out:
# Player_Name_x    456
# PA               456
# AB               456
# Hits             456
# R                456
# HR               456
# RBI              456
# SB               456
# BA               456
# xBA              456
# OBP              456
# BABIP            456
# BABIP.1          456
# ISO              456
# ISO.1            456
# SLG              456
# SLG.1            456
# wOBA             456
# wOBA.1           456
# xwOBA            456
# BB/PA            456
# K/PA             456
# Launch_Speed     456
# Launch_Angle     456
# Whiffs           456
# Swings           456
# Takes            456
# wRC+             456
# WAR              456
# playerid_x       456
# Player_Name_y    456
# Team             456
# GB/FB            456
# LD%              456
# GB%              456
# FB%              456
# HR/FB            456
# O-Swing%         456
# Z-Swing%         456
# Swing%           456
# O-Contact%       456
# Z-Contact%       456
# Contact%         456
# ...

# %%
# rename columns to make easier to analyze

merged_2015_v2.rename(columns={'Player_Name_x':'Player_Name', 'BB/PA' :'BBperPA', 'K/PA':'KperPA',
                               'playerid_x':'playerid', 'GB/FB':'GBperFB', 'LD%':'LDperc', 'GB%':'GBperc', 'FB%':'FBperc',
                               'HR/FB':'HRperFB', 'O-Swing%':'O-Swingperc', 'Z-Swing%':'Z-Swingperc', 'Swing%':'Swingperc', 
                               'O-Contact%':'O-Contactperc', 'Z-Contact%':'Z-Contactperc', 'Contact%':'Contactperc', 
                               'Zone%':'Zoneperc', 'F-Strike%':'FStrikeperc', 'SwStr%':'SwStrperc', 'Pull%':'Pullperc',
                               'Cent%':'Centperc', 'Oppo%':'Oppoperc'}, inplace=True)
merged_2016_v2.rename(columns={'Player_Name_x':'Player_Name', 'BB/PA' :'BBperPA', 'K/PA':'KperPA',
                               'playerid_x':'playerid', 'GB/FB':'GBperFB', 'LD%':'LDperc', 'GB%':'GBperc', 'FB%':'FBperc',
                               'HR/FB':'HRperFB', 'O-Swing%':'O-Swingperc', 'Z-Swing%':'Z-Swingperc', 'Swing%':'Swingperc', 
                               'O-Contact%':'O-Contactperc', 'Z-Contact%':'Z-Contactperc', 'Contact%':'Contactperc', 
                               'Zone%':'Zoneperc', 'F-Strike%':'FStrikeperc', 'SwStr%':'SwStrperc', 'Pull%':'Pullperc',
                               'Cent%':'Centperc', 'Oppo%':'Oppoperc'}, inplace=True)
merged_2017_v2.rename(columns={'Player_Name_x':'Player_Name', 'BB/PA' :'BBperPA', 'K/PA':'KperPA',
                               'playerid_x':'playerid', 'GB/FB':'GBperFB', 'LD%':'LDperc', 'GB%':'GBperc', 'FB%':'FBperc',
                               'HR/FB':'HRperFB', 'O-Swing%':'O-Swingperc', 'Z-Swing%':'Z-Swingperc', 'Swing%':'Swingperc', 
                               'O-Contact%':'O-Contactperc', 'Z-Contact%':'Z-Contactperc', 'Contact%':'Contactperc', 
                               'Zone%':'Zoneperc', 'F-Strike%':'FStrikeperc', 'SwStr%':'SwStrperc', 'Pull%':'Pullperc',
                               'Cent%':'Centperc', 'Oppo%':'Oppoperc'}, inplace=True)

# %%
# check the data after renaming
merged_2017_v2.head()
# Out:
#      Player_Name   PA   AB  Hits    R  HR  RBI  SB     BA    xBA    OBP  \
# 0     A.J. Ellis  163  143    30   17   6   14   0  0.210  0.197  0.298
# 1   A.J. Pollock  466  425   113   73  14   49  20  0.266  0.265  0.330
# 2  Aaron Altherr  412  372   101   58  19   65   5  0.272  0.244  0.340
# 3    Aaron Hicks  361  301    80   54  15   52  10  0.266  0.233  0.372
# 4    Aaron Judge  678  542   154  128  52  114   9  0.284  0.278  0.422
#
#    BABIP  BABIP.1    ISO  ISO.1    SLG  SLG.1   wOBA  wOBA.1  xwOBA  BBperPA  \
# 0  0.222    0.222  0.161  0.161  0.371  0.371  0.294   0.294  0.273    0.074
# 1  0.291    0.291  0.205  0.205  0.471  0.471  0.340   0.347  0.331    0.075
# 2  0.328    0.328  0.245  0.245  0.516  0.516  0.359   0.367  0.330    0.078
# 3  0.290    0.290  0.209  0.209  0.475  0.475  0.363   0.367  0.335    0.141
# 4  0.357    0.357  0.343  0.343  0.627  0.627  0.430   0.441  0.446    0.187
#
# ...

# %%
# two player names columns after merging (short/full name differences) and player_id is now our index so we'll drop that too
merged_2015_v2.drop(['Player_Name_y', 'Team', 'playerid_y', 'BABIP.1', 'ISO.1', 'SLG.1', 'wOBA.1'], axis=1, inplace=True)
merged_2016_v2.drop(['Player_Name_y', 'Team', 'playerid_y', 'BABIP.1', 'ISO.1', 'SLG.1', 'wOBA.1'], axis=1, inplace=True)
merged_2017_v2.drop(['Player_Name_y', 'Team', 'playerid_y', 'BABIP.1', 'ISO.1', 'SLG.1', 'wOBA.1'], axis=1, inplace=True)

# %%
merged_2017_v2.head()
# Out:
#      Player_Name   PA   AB  Hits    R  HR  RBI  SB     BA    xBA    OBP  \
# 0     A.J. Ellis  163  143    30   17   6   14   0  0.210  0.197  0.298
# 1   A.J. Pollock  466  425   113   73  14   49  20  0.266  0.265  0.330
# 2  Aaron Altherr  412  372   101   58  19   65   5  0.272  0.244  0.340
# 3    Aaron Hicks  361  301    80   54  15   52  10  0.266  0.233  0.372
# 4    Aaron Judge  678  542   154  128  52  114   9  0.284  0.278  0.422
#
#    BABIP    ISO    SLG   wOBA  xwOBA  BBperPA  KperPA  Launch_Speed  \
# 0  0.222  0.161  0.371  0.294  0.273    0.074   0.178          80.8
# 1  0.291  0.205  0.471  0.340  0.331    0.075   0.152          82.9
# 2  0.328  0.245  0.516  0.359  0.330    0.078   0.252          83.3
# 3  0.290  0.209  0.475  0.363  0.335    0.141   0.186          83.0
# 4  0.357  0.343  0.627  0.430  0.446    0.187   0.307          85.1
#
#    Launch_Angle  Whiffs  Swings  Takes  wRC+  WAR  playerid  GBperFB  LDperc  \
# ...

# %%
# need to convert all percentages to floats
merged_2015_v2 ['LDperc'] = merged_2015_v2['LDperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['LDperc'] = merged_2016_v2['LDperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['LDperc'] = merged_2017_v2['LDperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['GBperc'] = merged_2015_v2['GBperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['GBperc'] = merged_2016_v2['GBperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['GBperc'] = merged_2017_v2['GBperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['FBperc'] = merged_2015_v2['FBperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['FBperc'] = merged_2016_v2['FBperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['FBperc'] = merged_2017_v2['FBperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['HRperFB'] = merged_2015_v2['HRperFB'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['HRperFB'] = merged_2016_v2['HRperFB'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['HRperFB'] = merged_2017_v2['HRperFB'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['O-Swingperc'] = merged_2015_v2['O-Swingperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['O-Swingperc'] = merged_2016_v2['O-Swingperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['O-Swingperc'] = merged_2017_v2['O-Swingperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['Z-Swingperc'] = merged_2015_v2['Z-Swingperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['Z-Swingperc'] = merged_2016_v2['Z-Swingperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['Z-Swingperc'] = merged_2017_v2['Z-Swingperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['Swingperc'] = merged_2015_v2['Swingperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['Swingperc'] = merged_2016_v2['Swingperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['Swingperc'] = merged_2017_v2['Swingperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['O-Contactperc'] = merged_2015_v2['O-Contactperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['O-Contactperc'] = merged_2016_v2['O-Contactperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['O-Contactperc'] = merged_2017_v2['O-Contactperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['Z-Contactperc'] = merged_2015_v2['Z-Contactperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['Z-Contactperc'] = merged_2016_v2['Z-Contactperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['Z-Contactperc'] = merged_2017_v2['Z-Contactperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['Contactperc'] = merged_2015_v2['Contactperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['Contactperc'] = merged_2016_v2['Contactperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['Contactperc'] = merged_2017_v2['Contactperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['Zoneperc'] = merged_2015_v2['Zoneperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['Zoneperc'] = merged_2016_v2['Zoneperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['Zoneperc'] = merged_2017_v2['Zoneperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['FStrikeperc'] = merged_2015_v2['FStrikeperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['FStrikeperc'] = merged_2016_v2['FStrikeperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['FStrikeperc'] = merged_2017_v2['FStrikeperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['SwStrperc'] = merged_2015_v2['SwStrperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['SwStrperc'] = merged_2016_v2['SwStrperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['SwStrperc'] = merged_2017_v2['SwStrperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['Pullperc'] = merged_2015_v2['Pullperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['Pullperc'] = merged_2016_v2['Pullperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['Pullperc'] = merged_2017_v2['Pullperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['Centperc'] = merged_2015_v2['Centperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['Centperc'] = merged_2016_v2['Centperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['Centperc'] = merged_2017_v2['Centperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2015_v2 ['Oppoperc'] = merged_2015_v2['Oppoperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2016_v2 ['Oppoperc'] = merged_2016_v2['Oppoperc'].replace('%', ' ', regex=True).astype('float')/100
merged_2017_v2 ['Oppoperc'] = merged_2017_v2['Oppoperc'].replace('%', ' ', regex=True).astype('float')/100

# %%
merged_2017_v2.sort_values(by='Contactperc', ascending=False)
# Out:
#               Player_Name   PA   AB  Hits    R  HR  RBI  SB     BA    xBA  \
# 40       Asdrubal Cabrera  540  479   134   66  14   59   3  0.280  0.264
# 177           Greg Garcia  290  241    61   27   2   20   2  0.253  0.242
# 169          Gary Sanchez  525  471   131   79  33   90   2  0.278  0.285
# 433       Whit Merrifield  630  587   169   80  19   78  34  0.288  0.258
# 389        Salvador Perez  499  471   126   57  27   80   1  0.268  0.272
# 309            Matt Adams  367  339    93   46  20   65   0  0.274  0.265
# 219     Jeimer Candelario  142  127    36   18   3   16   0  0.283  0.243
# 212        Jaycob Brugman  162  143    38   12   3   12   1  0.266  0.228
# 90       Cheslor Cuthbert  153  143    33   10   2   18   0  0.231  0.220
# 163      Ezequiel Carrera  325  287    81   38   8   20  10  0.282  0.220
# 403          Steve Pearce  348  313    79   38  13   37   0  0.252  0.239
# 216           Jedd Gyorko  481  426   116   52  20   67   6  0.272  0.237
# ...

# %%
# xwOBA does not seem to be highly correlated with the batted ball stats, i'll need to go back to the drawing board here
merged_2017_v2.corr().sort_values('xwOBA', ascending=False)
# Out:
#                      PA        AB      Hits         R        HR       RBI  \
# xwOBA          0.518200  0.477748  0.525724  0.590240  0.684163  0.663709
# wRC+           0.535055  0.505313  0.597258  0.652327  0.679186  0.661240
# wOBA           0.537792  0.507624  0.602689  0.661254  0.680479  0.669828
# xBA            0.503943  0.500490  0.600770  0.518118  0.410200  0.548357
# SLG            0.522764  0.507475  0.580063  0.633857  0.777029  0.717765
# OBP            0.468414  0.425660  0.534334  0.581905  0.442942  0.503208
# HR             0.766372  0.747548  0.726646  0.806367  1.000000  0.904685
# ISO            0.399265  0.377417  0.384149  0.503859  0.804268  0.640781
# RBI            0.888540  0.878008  0.877766  0.876397  0.904685  1.000000
# WAR            0.653017  0.624746  0.715526  0.778294  0.683588  0.704123
# Launch_Speed   0.358465  0.343163  0.343811  0.370303  0.534810  0.522836
# R              0.941876  0.927641  0.936856  1.000000  0.806367  0.876397
# ...

# %%
# also saving merged_v2 stats datasets for future use
merged_2015_v2.to_csv("C:/Users/avitosky/Documents/Baseball Project/merged_2015_v2.csv")
merged_2016_v2.to_csv("C:/Users/avitosky/Documents/Baseball Project/merged_2016_v2.csv")
merged_2017_v2.to_csv("C:/Users/avitosky/Documents/Baseball Project/merged_2017_v2.csv")
