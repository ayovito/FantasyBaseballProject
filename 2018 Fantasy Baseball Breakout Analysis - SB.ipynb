# %%
# start looking at SBs, SBs per PA, SBs across seasons, include sprint speed, SBs correlate to other variables?

# %%
import pandas as pd
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
pd.options.display.max_columns = None
# %matplotlib inline
pd.set_option("display.max_rows",500)

# %%
# read in fangrapghs speed data
fangraphs_speed_2017 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/fangraphs_speed_2017.csv")

# %%
fangraphs_speed_2017.rename(columns={'Name':'Player_Name'}, inplace=True)

# %%
# get a sense again for what our data looks like
fangraphs_speed_2017.sort_values(by='Spd', ascending=False)
# Out:
#              Player_Name          Team  Age   AB   PA    H  3B  SB  CS  IFH  \
# 380       Billy Hamilton          Reds   26  582  633  144  11  59  13   19
# 137          Trea Turner     Nationals   24  412  447  117   6  46   8   22
# 258           Dee Gordon       Marlins   29  653  695  201   9  60  16   22
# 277        Gregor Blanco  Diamondbacks   33  224  256   55   3  15   1    4
# 420     Franklin Barreto     Athletics   21   71   76   14   2   2   0    3
# 262         Byron Buxton         Twins   23  462  511  117   6  29   1   16
# 413          Alen Hanson         - - -   24  217  234   48   3  11   3    7
# 114           Lane Adams        Braves   27  109  122   30   1  10   0    4
# 435        Danny Santana         - - -   26  168  178   34   2   7   0    3
# 375          Rajai Davis         - - -   36  336  366   79   2  29   7   13
# 302       Ehire Adrianza         Twins   27  162  186   43   2   8   1    2
# ...

# %%
fangraphs_speed_2017.count()
# Out:
# Player_Name    476
# Team           476
# Age            476
# AB             476
# PA             476
# H              476
# 3B             476
# SB             476
# CS             476
# IFH            476
# BU             476
# BsR            476
# Spd            476
# playerid       476
# dtype: int64

# %%
# read in savant speed data
#savant_sprint_speed_2017 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/savant_sprint_speed_2017.csv", 
                                       encoding='cp1252')

# %%
#savant_sprint_speed_2017.sort_values(by='Sprint_Speed', ascending=False)
# Out:
#                Player_Name  Sprint_Speed
# 0             Byron Buxton          30.2
# 1           Billy Hamilton          30.1
# 2         Magneuris Sierra          29.9
# 3           Bradley Zimmer          29.9
# 4               Dee Gordon          29.7
# 5             Amed Rosario          29.7
# 6         Delino DeShields          29.6
# 7             Raimel Tapia          29.5
# 8          Franchy Cordero          29.5
# 9             Keon Broxton          29.5
# 13              Adam Engel          29.3
# 14            Mallex Smith          29.3
# 12            Yoan Moncada          29.3
# 11             Rajai Davis          29.3
# 10           Manuel Margot          29.3
# 15             Trea Turner          29.2
# 16            Lorenzo Cain          29.1
# 17            Derek Fisher          29.1
# 18            Zack Granite          29.1
# 19              Lane Adams          29.1
# 20           Nick Williams          29.0
# 21             Wilmer Difo          29.0
# ...

# %%
#savant_sprint_speed_2017.count()
# Out:
# Player_Name     504
# Sprint_Speed    504
# dtype: int64

# %%
#savant_sprint_speed_2017.count()
# Out:
# Player_Name     0
# Sprint_Speed    0
# dtype: int64

# %%
#fangraphs_speed_2017['Player_Name'] = fangraphs_speed_2017['Player_Name'].replace({'Cam Perkins': 'Cameron Perkins',
                                        #'Eric Young': 'Eric Young Jr.', 'Gregory Bird' : 'Greg Bird', 
                                        #'J.T. Riddle': 'JT Riddle', 'Nick Castellanos': 'Nicholas Castellanos', 
                                        #'Nick Delmonico': 'Nicky Delmonico', 'Nori Aoki': 'Norichika Aoki', 
                                       #'Yulieski Gurriel': 'Yuli Gurriel'})

# %%
#fangraphs_speed_2017.set_index('Player_Name', drop=True)
# Out:
#                               Team  Age   AB   PA    H  3B  SB  CS  IFH  BU  \
# Player_Name
# Mike Trout                  Angels   25  402  507  123   3  22   4   13   0
# J.D. Martinez                - - -   29  432  489  131   3   4   0    7   0
# Aaron Judge                Yankees   25  542  678  154   3   9   4    5   0
# Joey Votto                    Reds   33  559  707  179   1   5   1    5   0
# Rhys Hoskins              Phillies   24  170  212   44   0   2   0    2   0
# Bryce Harper             Nationals   24  420  492  134   1   4   2   13   2
# Charlie Blackmon           Rockies   31  644  725  213  14  14  10   16   4
# Matt Olson               Athletics   23  189  216   49   0   0   0    1   3
# Giancarlo Stanton          Marlins   27  597  692  168   0   2   2   11   0
# Freddie Freeman             Braves   27  440  514  135   2   8   5   10   0
# Jose Altuve                 Astros   27  590  662  204   4  32   6   30   8
# ...

# %%
savant_sprint_speed_2017.set_index('Player_Name', drop=True)
# Out:
#                        Sprint_Speed
# Player_Name
#  Byron Buxton                  30.2
#  Billy Hamilton                30.1
#  Magneuris Sierra              29.9
#  Bradley Zimmer                29.9
#  Dee Gordon                    29.7
#  Amed Rosario                  29.7
#  Delino DeShields              29.6
#  Raimel Tapia                  29.5
#  Franchy Cordero               29.5
#  Keon Broxton                  29.5
#  Manuel Margot                 29.3
#  Rajai Davis                   29.3
#  Yoan Moncada                  29.3
#  Adam Engel                    29.3
#  Mallex Smith                  29.3
#  Trea Turner                   29.2
#  Lorenzo Cain                  29.1
#  Derek Fisher                  29.1
#  Zack Granite                  29.1
#  Lane Adams                    29.1
#  Nick Williams                 29.0
#  Wilmer Difo                   29.0
#  Ozzie Albies                  28.9
#  Kevin Kiermaier               28.9
# ...
