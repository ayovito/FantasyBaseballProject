# %% [markdown]
# # Project Title: Fantasy Baseball 2018 Advanced Metrics Data Exploration
# Project goal: Uncover undervalued players, make predictions for 2018 statistics

# %% [markdown]
# Advanced metrics were first collected by MLB in 2015 meaning I'll use 2015, 2016, 2017 data.
#
# I initially selected a minimum of 50 ABs but seeing mostly pitchers under 75 ABs, I decided to make 75 ABs the minimum.
#
# This notebook will be for cleaning and merging data from 2015, 2016, and 2017 from MLB Baseball Savant and FanGraphs

# %% [markdown]
# MLB Savant Data Dictionary:
#
# pitches - number of pitches seen by the player in that specific season
#
# player_id - unique player id, will be useful for year to year comparisons
#
# player_name - Player's name
#
# total_pitches - number of pitches seen by the player in that specific season
#
# pitch percent - percentage of pitches seen? not exactly sure but column consists of '100' for every player
#
# ba - batting average
#
# iso - isolated power
#
# babip - batting average on balls in play
#
# slg - slugging percentage
#
# woba - weighted on-base average
#
# xwoba - expected weighted on-base average
#
# xba - expected batting average
#
# hits - total base hits
#
# abs - total at bats
#
# launch_speed - average launch speed off of bat
#
# launch_angle - average launch angle
#
# spin_rate - average spin rate
#
# velocity - average exit velocity
#
# effective_speed - average effective speed
#
# whiffs - how many swings and misses
#
# swings - number of swings
#
# takes - number of pitches taken
#
# eff_min_vel - effective minimum velocity?
#
# release_extension - release extension?
#
# posX_int_start_distance - starting distance from each position in the field

# %%
# import packages
import pandas as pd

# %%
# read in 2015, 2016, and 2017 baseball savant data
savant_2015 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/savant_data_2015.csv")
savant_2016 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/savant_data_2016.csv")
savant_2017 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/savant_data_2017.csv")

# %%
# sort players by alphabetical order for indexing
savant_2015 = savant_2015.sort_values(by='player_name')
savant_2016 = savant_2016.sort_values(by='player_name')
savant_2017 = savant_2017.sort_values(by='player_name')

# %%
# reset index in savant data for merging later
savant_2015 = savant_2015.reset_index(drop=True)
savant_2016 = savant_2016.reset_index(drop=True)
savant_2017 = savant_2017.reset_index(drop=True)

# %%
# look at background info, mostly floats and ints with one object (player_name)
savant_2015.info()
print("-------------------------------------")
savant_2016.info()
print("-------------------------------------")
savant_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 31 columns):
# pitches                    467 non-null int64
# player_id                  467 non-null int64
# player_name                467 non-null object
# total_pitches              467 non-null int64
# pitch_percent              467 non-null float64
# ba                         467 non-null float64
# iso                        467 non-null float64
# babip                      467 non-null float64
# slg                        467 non-null float64
# woba                       467 non-null float64
# xwoba                      467 non-null float64
# xba                        467 non-null float64
# hits                       467 non-null int64
# abs                        467 non-null int64
# launch_speed               467 non-null float64
# launch_angle               467 non-null float64
# spin_rate                  467 non-null int64
# velocity                   467 non-null float64
# effective_speed            467 non-null float64
# whiffs                     467 non-null int64
# swings                     467 non-null int64
# takes                      467 non-null int64
# eff_min_vel                467 non-null float64
# release_extension          467 non-null float64
# pos3_int_start_distance    467 non-null int64
# pos4_int_start_distance    467 non-null int64
# pos5_int_start_distance    467 non-null int64
# pos6_int_start_distance    467 non-null int64
# pos7_int_start_distance    467 non-null int64
# pos8_int_start_distance    467 non-null int64
# pos9_int_start_distance    467 non-null int64
# dtypes: float64(14), int64(16), object(1)
# memory usage: 113.2+ KB
# -------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 31 columns):
# pitches                    459 non-null int64
# player_id                  459 non-null int64
# player_name                459 non-null object
# total_pitches              459 non-null int64
# pitch_percent              459 non-null float64
# ba                         459 non-null float64
# iso                        459 non-null float64
# babip                      459 non-null float64
# slg                        459 non-null float64
# woba                       459 non-null float64
# xwoba                      459 non-null float64
# xba                        459 non-null float64
# hits                       459 non-null int64
# abs                        459 non-null int64
# launch_speed               459 non-null float64
# launch_angle               459 non-null float64
# spin_rate                  459 non-null int64
# velocity                   459 non-null float64
# effective_speed            459 non-null float64
# whiffs                     459 non-null int64
# swings                     459 non-null int64
# takes                      459 non-null int64
# eff_min_vel                459 non-null float64
# release_extension          459 non-null float64
# pos3_int_start_distance    459 non-null int64
# pos4_int_start_distance    459 non-null int64
# pos5_int_start_distance    459 non-null int64
# pos6_int_start_distance    459 non-null int64
# pos7_int_start_distance    459 non-null int64
# pos8_int_start_distance    459 non-null int64
# pos9_int_start_distance    459 non-null int64
# dtypes: float64(14), int64(16), object(1)
# memory usage: 111.2+ KB
# -------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 31 columns):
# pitches                    456 non-null int64
# player_id                  456 non-null int64
# player_name                456 non-null object
# total_pitches              456 non-null int64
# pitch_percent              456 non-null int64
# ba                         456 non-null float64
# iso                        456 non-null float64
# babip                      456 non-null float64
# slg                        456 non-null float64
# woba                       456 non-null float64
# xwoba                      456 non-null float64
# xba                        456 non-null float64
# hits                       456 non-null int64
# abs                        456 non-null int64
# launch_speed               456 non-null float64
# launch_angle               456 non-null float64
# spin_rate                  456 non-null int64
# velocity                   456 non-null float64
# effective_speed            456 non-null float64
# whiffs                     456 non-null int64
# swings                     456 non-null int64
# takes                      456 non-null int64
# eff_min_vel                456 non-null float64
# release_extension          456 non-null float64
# pos3_int_start_distance    456 non-null int64
# pos4_int_start_distance    456 non-null int64
# pos5_int_start_distance    456 non-null int64
# pos6_int_start_distance    456 non-null int64
# pos7_int_start_distance    456 non-null int64
# pos8_int_start_distance    456 non-null int64
# pos9_int_start_distance    456 non-null int64
# dtypes: float64(13), int64(17), object(1)
# memory usage: 110.5+ KB

# %%
# describe the 2015 data
savant_2015.describe()
# Out:
#            pitches      player_id  total_pitches  pitch_percent          ba  \
# count   467.000000     467.000000     467.000000          467.0  467.000000
# mean   1422.134904  496932.550321    1422.134904          100.0    0.249657
# std     737.701078   81031.114490     737.701078            0.0    0.037963
# min     278.000000  116338.000000     278.000000          100.0    0.125000
# 25%     772.000000  452454.500000     772.000000          100.0    0.228000
# 50%    1415.000000  500208.000000    1415.000000          100.0    0.254000
# 75%    2049.000000  545839.500000    2049.000000          100.0    0.276000
# max    3021.000000  656941.000000    3021.000000          100.0    0.338000
#
#               iso       babip         slg        woba       xwoba  \
# count  467.000000  467.000000  467.000000  467.000000  467.000000
# mean     0.148099    0.296062    0.397730    0.310516    0.304615
# std      0.059756    0.041732    0.080086    0.046327    0.044904
# min      0.000000    0.181000    0.152000    0.177000    0.177000
# 25%      0.104000    0.267000    0.344500    0.283500    0.277000
# 50%      0.147000    0.299000    0.400000    0.313000    0.302000
# 75%      0.188000    0.324000    0.449000    0.339000    0.333000
# max      0.356000    0.412000    0.649000    0.467000    0.446000
#
#                 ...                   takes  eff_min_vel  release_extension  \
# count           ...              467.000000   467.000000         467.000000
# mean            ...              743.873662    -0.621413           6.014518
# std             ...              402.578256     0.210588           0.087200
# min             ...              128.000000    -1.200000           5.780000
# 25%             ...              391.000000    -0.800000           5.960000
# 50%             ...              709.000000    -0.600000           6.010000
# 75%             ...             1033.000000    -0.500000           6.080000
# max             ...             1848.000000     0.000000           6.290000
#
#        pos3_int_start_distance  pos4_int_start_distance  \
# count               467.000000               467.000000
# mean                109.160600               148.817987
# std                   3.311106                 3.424705
# min                  96.000000               139.000000
# 25%                 107.000000               147.000000
# 50%                 109.000000               149.000000
# 75%                 112.000000               150.000000
# max                 117.000000               169.000000
#
#        pos5_int_start_distance  pos6_int_start_distance  \
# count               467.000000               467.000000
# mean                109.513919               146.278373
# std                   8.100583                 1.834231
# min                  85.000000               139.000000
# 25%                 103.500000               145.000000
# 50%                 111.000000               146.000000
# 75%                 115.000000               147.500000
# max                 141.000000               152.000000
#
#        pos7_int_start_distance  pos8_int_start_distance  \
# count               467.000000               467.000000
# mean                291.475375               311.468951
# std                   7.941642                 5.267990
# min                 266.000000               295.000000
# 25%                 287.000000               308.000000
# 50%                 293.000000               312.000000
# 75%                 297.000000               315.000000
# max                 310.000000               326.000000
#
#        pos9_int_start_distance
# count               467.000000
# mean                291.321199
# std                   6.671286
# min                 271.000000
# 25%                 287.000000
# 50%                 292.000000
# 75%                 296.000000
# max                 309.000000
#
# [8 rows x 30 columns]

# %%
# describe the 2016 data
savant_2016.describe()
# Out:
#            pitches      player_id  total_pitches  pitch_percent          ba  \
# count   459.000000     459.000000     459.000000          459.0  459.000000
# mean   1472.324619  512616.934641    1472.324619          100.0    0.250930
# std     758.356172   78968.790969     758.356172            0.0    0.036263
# min     283.000000  120074.000000     283.000000          100.0    0.094000
# 25%     811.000000  456273.000000     811.000000          100.0    0.228000
# 50%    1372.000000  518692.000000    1372.000000          100.0    0.253000
# 75%    2108.000000  572156.500000    2108.000000          100.0    0.275000
# max    3014.000000  666560.000000    3014.000000          100.0    0.348000
#
#               iso       babip         slg        woba       xwoba  \
# count  459.000000  459.000000  459.000000  459.000000  459.000000
# mean     0.156190    0.296978    0.407109    0.316893    0.311919
# std      0.058502    0.041438    0.076767    0.043414    0.040891
# min      0.008000    0.135000    0.153000    0.111000    0.185000
# 25%      0.114500    0.271000    0.352000    0.286000    0.282000
# 50%      0.152000    0.298000    0.411000    0.320000    0.312000
# 75%      0.194000    0.322500    0.458500    0.346000    0.339000
# max      0.358000    0.411000    0.657000    0.430000    0.459000
#
#                 ...                   takes  eff_min_vel  release_extension  \
# count           ...              459.000000   459.000000         459.000000
# mean            ...              776.413943    -0.537473           6.053420
# std             ...              415.714310     0.212263           0.060611
# min             ...              111.000000    -1.300000           5.850000
# 25%             ...              417.000000    -0.700000           6.010000
# 50%             ...              715.000000    -0.500000           6.050000
# 75%             ...             1092.500000    -0.400000           6.095000
# max             ...             1813.000000     0.200000           6.230000
#
#        pos3_int_start_distance  pos4_int_start_distance  \
# count               459.000000               459.000000
# mean                108.657952               149.771242
# std                   3.513946                 3.895182
# min                  98.000000               140.000000
# 25%                 106.000000               148.000000
# 50%                 108.000000               149.000000
# 75%                 112.000000               151.000000
# max                 118.000000               171.000000
#
#        pos5_int_start_distance  pos6_int_start_distance  \
# count               459.000000                459.00000
# mean                110.655773                146.12854
# std                   8.323378                  1.91262
# min                  88.000000                140.00000
# 25%                 104.500000                145.00000
# 50%                 112.000000                146.00000
# 75%                 115.000000                148.00000
# max                 142.000000                151.00000
#
#        pos7_int_start_distance  pos8_int_start_distance  \
# count               459.000000               459.000000
# mean                294.265795               315.760349
# std                   7.326087                 4.788915
# min                 269.000000               302.000000
# 25%                 290.000000               313.000000
# 50%                 296.000000               316.000000
# 75%                 299.500000               319.000000
# max                 309.000000               329.000000
#
#        pos9_int_start_distance
# count               459.000000
# mean                292.583878
# std                   6.207039
# min                 276.000000
# 25%                 288.000000
# 50%                 293.000000
# 75%                 297.000000
# max                 310.000000
#
# [8 rows x 30 columns]

# %%
# describe the 2017 data
savant_2017.describe()
# Out:
#            pitches      player_id  total_pitches  pitch_percent          ba  \
# count   456.000000     456.000000     456.000000          456.0  456.000000
# mean   1497.885965  533524.054825    1497.885965          100.0    0.252110
# std     735.232199   74635.920683     735.232199            0.0    0.036177
# min     277.000000  134181.000000     277.000000          100.0    0.134000
# 25%     839.000000  462042.000000     839.000000          100.0    0.231000
# 50%    1465.000000  543388.500000    1465.000000          100.0    0.255000
# 75%    2117.750000  594784.500000    2117.750000          100.0    0.276250
# max    3028.000000  664056.000000    3028.000000          100.0    0.346000
#
#               iso       babip         slg        woba       xwoba  \
# count  456.000000  456.000000  456.000000  456.000000  456.000000
# mean     0.165803    0.298447    0.417908    0.322906    0.310399
# std      0.061619    0.042386    0.080516    0.044641    0.040224
# min      0.027000    0.145000    0.203000    0.181000    0.173000
# 25%      0.120750    0.274000    0.366750    0.295000    0.283000
# 50%      0.162000    0.299000    0.417500    0.323000    0.311000
# 75%      0.207250    0.328000    0.471000    0.350000    0.336000
# max      0.392000    0.420000    0.690000    0.451000    0.446000
#
#                 ...                   takes  eff_min_vel  release_extension  \
# count           ...              456.000000   456.000000         456.000000
# mean            ...              791.500000    -0.489474           6.023575
# std             ...              405.669567     0.146080           0.069959
# min             ...              115.000000    -1.000000           5.750000
# 25%             ...              432.250000    -0.600000           5.980000
# 50%             ...              766.500000    -0.500000           6.020000
# 75%             ...             1114.750000    -0.400000           6.070000
# max             ...             1832.000000    -0.100000           6.210000
#
#        pos3_int_start_distance  pos4_int_start_distance  \
# count               456.000000               456.000000
# mean                109.572368               150.484649
# std                   3.637295                 3.787746
# min                  99.000000               142.000000
# 25%                 107.000000               148.000000
# 50%                 108.000000               150.000000
# 75%                 113.000000               151.000000
# max                 119.000000               167.000000
#
#        pos5_int_start_distance  pos6_int_start_distance  \
# count               456.000000               456.000000
# mean                111.054825               147.125000
# std                   7.402647                 2.064815
# min                  90.000000               142.000000
# 25%                 106.000000               146.000000
# 50%                 112.000000               147.000000
# 75%                 115.000000               149.000000
# max                 134.000000               153.000000
#
#        pos7_int_start_distance  pos8_int_start_distance  \
# count               456.000000               456.000000
# mean                295.041667               317.682018
# std                   7.036515                 4.969112
# min                 271.000000               303.000000
# 25%                 290.000000               314.000000
# 50%                 296.000000               318.000000
# 75%                 300.000000               321.000000
# max                 311.000000               331.000000
#
#        pos9_int_start_distance
# count               456.000000
# mean                293.769737
# std                   6.122346
# min                 274.000000
# 25%                 289.000000
# 50%                 294.000000
# 75%                 298.000000
# max                 309.000000
#
# [8 rows x 30 columns]

# %% [markdown]
# It looks like we have all of the same columns in the dataset so I'll explore all columns in 2017 dataset.
#
# I know that pitches, player_id, ba, iso, babip, slg, woba, xwoba, xba, hits, abs, whiffs, swings, takes are all relevant
# columns but I'm not sure about the others so I will explore them now.
#
# From the data above total_pitches is a mirror of pitches and pitch_percent only has values of 100 so I'll focus on the others

# %%
# launch speed may or may not be relevant, not a ton of variation in std
savant_2017['launch_speed'].describe()
# Out:
# count    456.000000
# mean      81.481140
# std        2.117513
# min       74.000000
# 25%       80.100000
# 50%       81.700000
# 75%       83.000000
# max       87.100000
# Name: launch_speed, dtype: float64

# %%
# simple correlation shows some correlation with woba (the most "catch-all stat in savant data) will keep the variable for now
savant_2017['launch_speed'].corr(savant_2017['woba'])
# Out:
# 0.47280094010323959

# %%
# launch angle is a good descriptor of consistency for well struck balls so we'll leave it, higher launch angle is better
savant_2017['launch_angle'].describe()
# Out:
# count    456.000000
# mean      15.921053
# std        4.018572
# min       -1.600000
# 25%       13.075000
# 50%       15.900000
# 75%       18.500000
# max       33.100000
# Name: launch_angle, dtype: float64

# %%
# not much correlation but a good varaible for us to keep
savant_2017['launch_angle'].corr(savant_2017['woba'])
# Out:
# 0.1817071200478004

# %%
# spin rate has a smaller std meaning that it is a relatively stable variable, more useful in pitching metrics than hitting
savant_2017['spin_rate'].describe()
# Out:
# count     456.000000
# mean     2217.614035
# std        30.625568
# min      2110.000000
# 25%      2196.000000
# 50%      2219.000000
# 75%      2241.250000
# max      2294.000000
# Name: spin_rate, dtype: float64

# %%
# with zero correlation to woba, we can get rid of it
savant_2017['spin_rate'].corr(savant_2017['woba'])
# Out:
# 0.0017834618157080977

# %%
# same story with velocity as with spin_rate
savant_2017['velocity'].describe()
# Out:
# count    456.000000
# mean      88.639254
# std        0.509832
# min       86.800000
# 25%       88.300000
# 50%       88.600000
# 75%       88.925000
# max       90.200000
# Name: velocity, dtype: float64

# %%
# again zero correlation so we'll drop it
savant_2017['velocity'].corr(savant_2017['woba'])
# Out:
# -0.0050709668877704211

# %%
# again same story with effective_speed as with spin_rate and velocity
savant_2017['effective_speed'].describe()
# Out:
# count    456.000000
# mean      88.148202
# std        0.544963
# min       86.120000
# 25%       87.770000
# 50%       88.150000
# 75%       88.490000
# max       89.710000
# Name: effective_speed, dtype: float64

# %%
# zero correlation so we'll drop it
savant_2017['effective_speed'].corr(savant_2017['woba'])
# Out:
# -0.0015943003117315719

# %%
# and again same story with eff_min_vel as with spin_rate, velocity, and effective_speed
savant_2017['eff_min_vel'].describe()
# Out:
# count    456.000000
# mean      -0.489474
# std        0.146080
# min       -1.000000
# 25%       -0.600000
# 50%       -0.500000
# 75%       -0.400000
# max       -0.100000
# Name: eff_min_vel, dtype: float64

# %%
# zero correlation so we'll drop it
savant_2017['eff_min_vel'].corr(savant_2017['woba'])
# Out:
# 8.514397583133259e-05

# %%
# and one more time, same story with eff_min_vel as with spin_rate, velocity, effective_speed, and eff_min_vel
savant_2017['release_extension'].describe()
# Out:
# count    456.000000
# mean       6.023575
# std        0.069959
# min        5.750000
# 25%        5.980000
# 50%        6.020000
# 75%        6.070000
# max        6.210000
# Name: release_extension, dtype: float64

# %%
# zero correlation so we'll drop it
savant_2017['release_extension'].corr(savant_2017['woba'])
# Out:
# -0.018583341838097341

# %%
# the posX_int_distance variables describe the depth of the fielders positioning for defensive player so we'll drop those too
# kept - pitches, player_id, player_name, ba, iso, babip, slg, woba, xwoba, xba, hits, abs, launch_speed, launch_angle, whiffs, swings, taken
# deleted - total_pitches, pitch_percent, spin_rate, velocity, effective_speed, eff_min_vel, release_extension, posX_int_distance variables

# %%
# drop specified columns from data
savant_2015.drop(['total_pitches', 'pitches', 'pitch_percent', 'abs', 'spin_rate', 'velocity',
                  'effective_speed', 'eff_min_vel', 'release_extension', 'pos3_int_start_distance',
                  'pos4_int_start_distance', 'pos5_int_start_distance', 'pos6_int_start_distance', 
                  'pos7_int_start_distance', 'pos8_int_start_distance', 'pos9_int_start_distance',
                  'ba', 'iso', 'babip', 'slg', 'woba'], axis=1, inplace=True)
savant_2016.drop(['total_pitches', 'pitches', 'pitch_percent', 'abs', 'spin_rate', 'velocity',
                  'effective_speed', 'eff_min_vel', 'release_extension', 'pos3_int_start_distance',
                  'pos4_int_start_distance', 'pos5_int_start_distance', 'pos6_int_start_distance', 
                  'pos7_int_start_distance', 'pos8_int_start_distance', 'pos9_int_start_distance',
                  'ba', 'iso', 'babip', 'slg', 'woba'], axis=1, inplace=True)
savant_2017.drop(['total_pitches', 'pitches', 'pitch_percent', 'abs', 'spin_rate', 'velocity',
                  'effective_speed', 'eff_min_vel', 'release_extension', 'pos3_int_start_distance',
                  'pos4_int_start_distance', 'pos5_int_start_distance', 'pos6_int_start_distance', 
                  'pos7_int_start_distance', 'pos8_int_start_distance', 'pos9_int_start_distance',
                  'ba', 'iso', 'babip', 'slg', 'woba'], axis=1, inplace=True)

# %%
# show updated dataset
savant_2017.head()
# Out:
#    player_id    player_name  xwoba    xba  hits  launch_speed  launch_angle  \
# 0     454560     A.J. Ellis  0.273  0.197    30          80.8          16.5
# 1     572041   A.J. Pollock  0.331  0.265   113          82.9          10.7
# 2     571437  Aaron Altherr  0.330  0.244   101          83.3          14.3
# 3     543305    Aaron Hicks  0.335  0.233    80          83.0          16.5
# 4     592450    Aaron Judge  0.446  0.278   154          85.1          17.5
#
#    whiffs  swings  takes
# 0      52     270    365
# 1     139     737    995
# 2     212     708    878
# 3     154     579    896
# 4     429    1228   1756

# %% [markdown]
# To get a more holistic profile for each player, we'll need to import data from FanGraphs, drop what columns are redundant and then merge the two datasets together.

# %%
# read in 2015, 2016, and 2017 fangraphs data
fangraphs_2015 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/fangraphs_2015.csv")
fangraphs_2016 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/fangraphs_2016.csv")
fangraphs_2017 = pd.read_csv("C:/Users/avitosky/Documents/Baseball Project/fangraphs_2017.csv")

# %%
# savant data has minimum 75 ABs, fangraphs can only specify minimum PAs so set to 70 but included ABs in data
# need to drop < 75 ABs from each fangraphs dataset
fangraphs_2015 = fangraphs_2015[fangraphs_2015["AB"] >= 75]
fangraphs_2016 = fangraphs_2016[fangraphs_2016["AB"] >= 75]
fangraphs_2017 = fangraphs_2017[fangraphs_2017["AB"] >= 75]

# %%
# change fangraphs 'Name' column to 'player_name' to merge with savant data
fangraphs_2015.rename(columns={'Name':'player_name'}, inplace=True)
fangraphs_2016.rename(columns={'Name':'player_name'}, inplace=True)
fangraphs_2017.rename(columns={'Name':'player_name'}, inplace=True)

# %%
fangraphs_2015['player_name'] = fangraphs_2015['player_name'].replace({'Eric Young' : 'Eric Young Jr.', 
                                        'Gregory Bird': 'Greg Bird', 'Ivan De Jesus': 'Ivan De Jesus Jr.', 
                                        'John Mayberry': 'John Mayberry Jr.', 'Nick Castellanos': 'Nicholas Castellanos', 
                                        'Nori Aoki': 'Norichika Aoki'})
fangraphs_2016['player_name'] = fangraphs_2016['player_name'].replace({'Byung-ho Park': 'ByungHo Park',
                                        ' Ivan De Jesus': 'Ivan De Jesus Jr.', 'Nick Castellanos': 'Nicholas Castellanos', 
                                        'Nori Aoki': 'Norichika Aoki','Yulieski Gurriel': 'Yuli Gurriel'})
fangraphs_2017['player_name'] = fangraphs_2017['player_name'].replace({'Cam Perkins': 'Cameron Perkins',
                                        'Eric Young': 'Eric Young Jr.', 'Gregory Bird' : 'Greg Bird', 
                                        'J.T. Riddle': 'JT Riddle', 'Nick Castellanos': 'Nicholas Castellanos', 
                                        'Nick Delmonico': 'Nicky Delmonico', 'Nori Aoki': 'Norichika Aoki', 
                                        'Yulieski Gurriel': 'Yuli Gurriel'})

# %%
# sort fangraphs data by name
fangraphs_2015 = fangraphs_2015.sort_values(by='player_name')
fangraphs_2016 = fangraphs_2016.sort_values(by='player_name')
fangraphs_2017 = fangraphs_2017.sort_values(by='player_name')

# %%
# reset fangraphs index
fangraphs_2015 = fangraphs_2015.reset_index(drop=True)
fangraphs_2016 = fangraphs_2016.reset_index(drop=True)
fangraphs_2017 = fangraphs_2017.reset_index(drop=True)

# %%
# look at background info, mostly floats and ints with one object (player_name)
fangraphs_2015.info()
print("-------------------------------------")
fangraphs_2016.info()
print("-------------------------------------")
fangraphs_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 23 columns):
# player_name    467 non-null object
# Team           467 non-null object
# G              467 non-null int64
# AB             467 non-null int64
# PA             467 non-null int64
# HR             467 non-null int64
# R              467 non-null int64
# RBI            467 non-null int64
# SB             467 non-null int64
# BB%            467 non-null object
# K%             467 non-null object
# ISO            467 non-null float64
# BABIP          467 non-null float64
# AVG            467 non-null float64
# OBP            467 non-null float64
# SLG            467 non-null float64
# wOBA           467 non-null float64
# wRC+           467 non-null int64
# BsR            467 non-null float64
# Off            467 non-null float64
# Def            467 non-null float64
# WAR            467 non-null float64
# playerid       467 non-null int64
# dtypes: float64(10), int64(9), object(4)
# memory usage: 84.0+ KB
# -------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 23 columns):
# player_name    459 non-null object
# Team           459 non-null object
# G              459 non-null int64
# AB             459 non-null int64
# PA             459 non-null int64
# HR             459 non-null int64
# R              459 non-null int64
# RBI            459 non-null int64
# SB             459 non-null int64
# BB%            459 non-null object
# K%             459 non-null object
# ISO            459 non-null float64
# BABIP          459 non-null float64
# AVG            459 non-null float64
# OBP            459 non-null float64
# SLG            459 non-null float64
# wOBA           459 non-null float64
# wRC+           459 non-null int64
# BsR            459 non-null float64
# Off            459 non-null float64
# Def            459 non-null float64
# WAR            459 non-null float64
# playerid       459 non-null int64
# dtypes: float64(10), int64(9), object(4)
# memory usage: 82.6+ KB
# -------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 23 columns):
# player_name    456 non-null object
# Team           456 non-null object
# G              456 non-null int64
# AB             456 non-null int64
# PA             456 non-null int64
# HR             456 non-null int64
# R              456 non-null int64
# RBI            456 non-null int64
# SB             456 non-null int64
# BB%            456 non-null object
# K%             456 non-null object
# ISO            456 non-null float64
# BABIP          456 non-null float64
# AVG            456 non-null float64
# OBP            456 non-null float64
# SLG            456 non-null float64
# wOBA           456 non-null float64
# wRC+           456 non-null int64
# BsR            456 non-null float64
# Off            456 non-null float64
# Def            456 non-null float64
# WAR            456 non-null float64
# playerid       456 non-null int64
# dtypes: float64(10), int64(9), object(4)
# memory usage: 82.0+ KB

# %%
fangraphs_2017.head()
# Out:
#      player_name          Team    G   AB   PA  HR    R  RBI  SB     BB%  \
# 0     A.J. Ellis       Marlins   51  143  163   6   17   14   0   7.4 %
# 1   A.J. Pollock  Diamondbacks  112  425  466  14   73   49  20   7.5 %
# 2  Aaron Altherr      Phillies  107  372  412  19   58   65   5   7.8 %
# 3    Aaron Hicks       Yankees   88  301  361  15   54   52  10  14.1 %
# 4    Aaron Judge       Yankees  155  542  678  52  128  114   9  18.7 %
#
#      ...       AVG    OBP    SLG   wOBA  wRC+  BsR   Off  Def  WAR  playerid
# 0    ...     0.210  0.298  0.371  0.294    80 -1.8  -6.0  2.8  0.2      5677
# 1    ...     0.266  0.330  0.471  0.340   103  2.6   4.2  1.8  2.1      9256
# 2    ...     0.272  0.340  0.516  0.359   120 -2.0   8.7 -8.6  1.3     11270
# 3    ...     0.266  0.372  0.475  0.363   127  2.5  14.4  6.4  3.3      5297
# 4    ...     0.284  0.422  0.627  0.430   173  0.0  60.8 -1.3  8.2     15640
#
# [5 rows x 23 columns]

# %%
# need to convert BB% and K% objects to floats
fangraphs_2015 ['BB%'] = fangraphs_2015['BB%'].replace('%', ' ', regex=True).astype('float')/100
fangraphs_2016 ['BB%'] = fangraphs_2016['BB%'].replace('%', ' ', regex=True).astype('float')/100
fangraphs_2017 ['BB%'] = fangraphs_2017['BB%'].replace('%', ' ', regex=True).astype('float')/100
fangraphs_2015 ['K%'] = fangraphs_2015['K%'].replace('%', ' ', regex=True).astype('float')/100
fangraphs_2016 ['K%'] = fangraphs_2016['K%'].replace('%', ' ', regex=True).astype('float')/100
fangraphs_2017 ['K%'] = fangraphs_2017['K%'].replace('%', ' ', regex=True).astype('float')/100

# %%
fangraphs_2017.head()
# Out:
#      player_name          Team    G   AB   PA  HR    R  RBI  SB    BB%  \
# 0     A.J. Ellis       Marlins   51  143  163   6   17   14   0  0.074
# 1   A.J. Pollock  Diamondbacks  112  425  466  14   73   49  20  0.075
# 2  Aaron Altherr      Phillies  107  372  412  19   58   65   5  0.078
# 3    Aaron Hicks       Yankees   88  301  361  15   54   52  10  0.141
# 4    Aaron Judge       Yankees  155  542  678  52  128  114   9  0.187
#
#      ...       AVG    OBP    SLG   wOBA  wRC+  BsR   Off  Def  WAR  playerid
# 0    ...     0.210  0.298  0.371  0.294    80 -1.8  -6.0  2.8  0.2      5677
# 1    ...     0.266  0.330  0.471  0.340   103  2.6   4.2  1.8  2.1      9256
# 2    ...     0.272  0.340  0.516  0.359   120 -2.0   8.7 -8.6  1.3     11270
# 3    ...     0.266  0.372  0.475  0.363   127  2.5  14.4  6.4  3.3      5297
# 4    ...     0.284  0.422  0.627  0.430   173  0.0  60.8 -1.3  8.2     15640
#
# [5 rows x 23 columns]

# %%
# from fangraphs will drop variables Team, G, ISO, BABIP, AVG, SLG, wOBA, Off, Def (both are cumulative stats, not rate stats)
# also drop playerid because it is not consistent from site to site
# drop specified columns from 2015 fangraphs data
fangraphs_2015.drop(['Team', 'G', 'Off', 'Def', 'BsR', 'playerid'], axis=1, inplace=True)
fangraphs_2016.drop(['Team', 'G', 'Off', 'Def', 'BsR', 'playerid'], axis=1, inplace=True)
fangraphs_2017.drop(['Team', 'G', 'Off', 'Def', 'BsR', 'playerid'], axis=1, inplace=True)

# %%
# merge 2015 fangraphs and savant data on index
merged_2015 = pd.merge(fangraphs_2015, savant_2015, right_index=True, left_index=True)
merged_2016 = pd.merge(fangraphs_2016, savant_2016, right_index=True, left_index=True)
merged_2017 = pd.merge(fangraphs_2017, savant_2017, right_index=True, left_index=True)

# %%
# check in to see what our merged data looks like
merged_2015.info()
print("-------------------------------------")
merged_2016.info()
print("-------------------------------------")
merged_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 27 columns):
# player_name_x    467 non-null object
# AB               467 non-null int64
# PA               467 non-null int64
# HR               467 non-null int64
# R                467 non-null int64
# RBI              467 non-null int64
# SB               467 non-null int64
# BB%              467 non-null float64
# K%               467 non-null float64
# ISO              467 non-null float64
# BABIP            467 non-null float64
# AVG              467 non-null float64
# OBP              467 non-null float64
# SLG              467 non-null float64
# wOBA             467 non-null float64
# wRC+             467 non-null int64
# WAR              467 non-null float64
# player_id        467 non-null int64
# player_name_y    467 non-null object
# xwoba            467 non-null float64
# xba              467 non-null float64
# hits             467 non-null int64
# launch_speed     467 non-null float64
# launch_angle     467 non-null float64
# whiffs           467 non-null int64
# swings           467 non-null int64
# takes            467 non-null int64
# dtypes: float64(13), int64(12), object(2)
# memory usage: 98.6+ KB
# -------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 27 columns):
# player_name_x    459 non-null object
# AB               459 non-null int64
# PA               459 non-null int64
# HR               459 non-null int64
# R                459 non-null int64
# RBI              459 non-null int64
# SB               459 non-null int64
# BB%              459 non-null float64
# K%               459 non-null float64
# ISO              459 non-null float64
# BABIP            459 non-null float64
# AVG              459 non-null float64
# OBP              459 non-null float64
# SLG              459 non-null float64
# wOBA             459 non-null float64
# wRC+             459 non-null int64
# WAR              459 non-null float64
# player_id        459 non-null int64
# player_name_y    459 non-null object
# xwoba            459 non-null float64
# xba              459 non-null float64
# hits             459 non-null int64
# launch_speed     459 non-null float64
# launch_angle     459 non-null float64
# whiffs           459 non-null int64
# swings           459 non-null int64
# takes            459 non-null int64
# dtypes: float64(13), int64(12), object(2)
# memory usage: 96.9+ KB
# -------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 27 columns):
# player_name_x    456 non-null object
# AB               456 non-null int64
# PA               456 non-null int64
# HR               456 non-null int64
# R                456 non-null int64
# RBI              456 non-null int64
# SB               456 non-null int64
# BB%              456 non-null float64
# K%               456 non-null float64
# ISO              456 non-null float64
# BABIP            456 non-null float64
# AVG              456 non-null float64
# OBP              456 non-null float64
# SLG              456 non-null float64
# wOBA             456 non-null float64
# wRC+             456 non-null int64
# WAR              456 non-null float64
# player_id        456 non-null int64
# player_name_y    456 non-null object
# xwoba            456 non-null float64
# xba              456 non-null float64
# hits             456 non-null int64
# launch_speed     456 non-null float64
# launch_angle     456 non-null float64
# whiffs           456 non-null int64
# swings           456 non-null int64
# takes            456 non-null int64
# dtypes: float64(13), int64(12), object(2)
# memory usage: 96.3+ KB

# %%
# we have same number of rows in each data set from before merge to after merge but just to double check, we'll look at each one
savant_2017
# Out:
#      player_id         player_name  xwoba    xba  hits  launch_speed  \
# 0       454560          A.J. Ellis  0.273  0.197    30          80.8
# 1       572041        A.J. Pollock  0.331  0.265   113          82.9
# 2       571437       Aaron Altherr  0.330  0.244   101          83.3
# 3       543305         Aaron Hicks  0.335  0.233    80          83.0
# 4       592450         Aaron Judge  0.446  0.278   154          85.1
# 5       501659     Abraham Almonte  0.301  0.231    40          83.1
# 6       594807         Adam Duvall  0.295  0.217   146          81.5
# 7       594809          Adam Eaton  0.319  0.228    27          81.9
# 8       641553          Adam Engel  0.223  0.164    50          76.4
# 9       624428        Adam Frazier  0.325  0.275   112          80.6
# 10      430945          Adam Jones  0.313  0.258   170          81.7
# 11      452252           Adam Lind  0.379  0.291    81          85.4
# 12      489267        Adam Rosales  0.226  0.189    65          80.3
# 13      608365     Addison Russell  0.306  0.240    84          82.7
# 14      588751  Adeiny Hechavarria  0.293  0.260    86          80.8
# 15      611177       Adonis Garcia  0.297  0.257    41          81.3
# 16      134181       Adrian Beltre  0.355  0.276   106          81.7
# 17      408236     Adrian Gonzalez  0.303  0.252    56          83.0
# 18      546991   Albert Almora Jr.  0.299  0.255    89          82.1
# 19      405395       Albert Pujols  0.326  0.268   143          84.5
# 20      444876     Alcides Escobar  0.265  0.243   150          79.2
# 21      649557        Aledmys Diaz  0.263  0.231    74          81.4
# 22      593700         Alen Hanson  0.230  0.194    48          78.5
# 23      488671          Alex Avila  0.401  0.272    82          86.4
# 24      608324        Alex Bregman  0.338  0.271   158          83.0
# 25      460086         Alex Gordon  0.300  0.224    99          81.0
# 26      502100        Alex Presley  0.303  0.281    77          78.4
# 27      506560      Alexi Amarista  0.234  0.216    40          79.0
# 28      642707       Allen Cordoba  0.270  0.217    42          77.0
# 29      642708        Amed Rosario  0.228  0.205    41          78.7
# ..         ...                 ...    ...    ...   ...           ...
# 426     571841            Ty Kelly  0.257  0.210    17          77.0
# 427     607385       Tyler Collins  0.280  0.196    29          83.9
# 428     452095       Tyler Flowers  0.347  0.264    89          81.8
# 429     489138         Tyler Moore  0.270  0.212    43          83.3
# 430     573135      Tyler Saladino  0.230  0.180    45          80.1
# 431     400121     Victor Martinez  0.344  0.271   100          84.2
# 432     456078  Welington Castillo  0.343  0.268    96          84.1
# 433     593160     Whit Merrifield  0.314  0.258   169          82.5
# 434     571976           Wil Myers  0.321  0.223   138          83.1
# 435     575929   Willson Contreras  0.336  0.244   104          81.5
# 436     591994        Willy Garcia  0.275  0.204    25          83.4
# 437     594694         Wilmer Difo  0.286  0.250    90          77.8
# 438     527038       Wilmer Flores  0.318  0.259    91          82.3
# 439     467092        Wilson Ramos  0.326  0.261    54          79.5
# 440     593428     Xander Bogaerts  0.283  0.232   156          81.0
# 441     425877       Yadier Molina  0.339  0.279   137          82.9
# 442     543228           Yan Gomes  0.281  0.202    79          81.2
# 443     650490          Yandy Diaz  0.331  0.266    41          87.1
# 444     500208   Yangervis Solarte  0.303  0.245   119          81.0
# 445     624577         Yasiel Puig  0.348  0.254   131          82.7
# 446     518735     Yasmani Grandal  0.288  0.216   108          81.9
# 447     630111       Yasmany Tomas  0.321  0.230    40          84.8
# 448     660162        Yoan Moncada  0.306  0.209    46          81.5
# 449     493316     Yoenis Cespedes  0.351  0.262    85          82.1
# 450     570560      Yolmer Sanchez  0.276  0.229   129          79.6
# 451     475174       Yonder Alonso  0.368  0.262   120          83.0
# 452     493329        Yuli Gurriel  0.327  0.283   158          85.1
# 453     488862       Yunel Escobar  0.330  0.272    96          84.3
# 454     446359         Zack Cozart  0.332  0.255   130          81.7
# 455     643335        Zack Granite  0.291  0.250    22          79.9
#
#      launch_angle  whiffs  swings  takes
# 0            16.5      52     270    365
# 1            10.7     139     737    995
# 2            14.3     212     708    878
# 3            16.5     154     579    896
# 4            17.5     429    1228   1756
# 5             8.3      97     363    403
# 6            22.8     312    1196   1278
# 7            14.3      39     188    252
# 8            17.8     218     628    672
# 9            14.6     108     803    940
# 10           17.8     325    1329    944
# 11           14.9      95     529    644
# 12           16.5     208     582    629
# 13           20.7     204     740    737
# 14           14.7     166     674    491
# 15           12.7      74     372    332
# 16           17.7     138     738    836
# 17           14.2     110     451    444
# 18           12.1     141     573    533
# 19           16.5     241    1172   1311
# 20           17.6     247    1186   1025
# 21           16.8     124     560    504
# 22           11.9     110     430    417
# 23           16.0     216     593   1016
# 24           21.1     170    1030   1264
# 25           17.3     241    1042   1142
# 26           14.4      92     502    560
# 27           17.3      69     357    341
# 28           10.0     107     377    474
# 29           12.5     127     355    284
# ..            ...     ...     ...    ...
# 426          13.9      37     165    266
# 427          23.6     100     315    382
# 428          14.4     176     687    729
# 429          21.2     116     392    377
# 430          16.6     119     484    660
# 431          16.2     124     773    877
# 432          18.5     154     626    819
# 433          20.4     210    1198   1160
# 434          19.3     305    1177   1484
# 435          12.5     231     759    832
# 436          16.4      65     208    269
# 437          11.2     180     701    630
# 438          20.0     125     760    706
# 439          11.0      85     402    316
# 440          12.7     222    1065   1472
# 441          20.4     197    1050    941
# 442          21.0     209     764    686
# 443           6.0      52     280    438
# 444          16.7     144     912    855
# 445          14.4     242     979   1134
# 446          20.3     248     887   1020
# 447          13.7     110     348    314
# 448          15.2     132     415    550
# 449          20.8     135     644    671
# 450          16.2     239    1000    989
# 451          20.4     255     976   1096
# 452          13.8     164     932    991
# 453           7.1     126     637    718
# 454          16.3     139     868   1249
# 455          15.4      10     160    265
#
# [456 rows x 10 columns]

# %%
# Zack Granite comes in at #455 in both datasets so looks like the merge was successful
fangraphs_2017
# Out:
#             player_name   AB   PA  HR    R  RBI  SB    BB%     K%    ISO  \
# 0            A.J. Ellis  143  163   6   17   14   0  0.074  0.178  0.161
# 1          A.J. Pollock  425  466  14   73   49  20  0.075  0.152  0.205
# 2         Aaron Altherr  372  412  19   58   65   5  0.078  0.252  0.245
# 3           Aaron Hicks  301  361  15   54   52  10  0.141  0.186  0.209
# 4           Aaron Judge  542  678  52  128  114   9  0.187  0.307  0.343
# 5       Abraham Almonte  172  195   3   26   14   2  0.103  0.236  0.134
# 6           Adam Duvall  587  647  31   78   99   5  0.060  0.263  0.232
# 7            Adam Eaton   91  107   2   24   13   3  0.131  0.168  0.165
# 8            Adam Engel  301  336   6   34   21   8  0.057  0.348  0.116
# 9          Adam Frazier  406  454   6   55   53   9  0.079  0.126  0.123
# 10           Adam Jones  597  635  26   82   73   2  0.043  0.178  0.181
# 11            Adam Lind  267  301  14   39   59   1  0.093  0.156  0.210
# 12         Adam Rosales  289  312   7   25   36   1  0.035  0.321  0.128
# 13      Addison Russell  352  385  12   52   43   2  0.075  0.236  0.179
# 14   Adeiny Hechavarria  330  348   8   37   30   4  0.037  0.193  0.145
# 15        Adonis Garcia  173  183   5   19   19   4  0.038  0.126  0.110
# 16        Adrian Beltre  340  389  17   47   71   1  0.100  0.134  0.221
# 17      Adrian Gonzalez  231  252   3   14   30   0  0.063  0.171  0.113
# 18    Albert Almora Jr.  299  323   8   39   46   1  0.059  0.164  0.147
# 19        Albert Pujols  593  636  23   53  101   3  0.058  0.146  0.145
# 20      Alcides Escobar  599  629   6   71   54   4  0.024  0.162  0.107
# 21         Aledmys Diaz  286  301   7   31   20   4  0.043  0.140  0.133
# 22          Alen Hanson  217  234   4   36   11  11  0.051  0.222  0.124
# 23           Alex Avila  311  376  14   41   49   0  0.165  0.319  0.183
# 24         Alex Bregman  556  626  19   88   71  17  0.088  0.155  0.191
# 25          Alex Gordon  476  541   9   52   45   7  0.083  0.233  0.107
# 26         Alex Presley  245  264   3   30   20   5  0.057  0.186  0.102
# 27       Alexi Amarista  168  176   3   22   19   1  0.040  0.216  0.113
# 28        Allen Cordoba  202  227   4   17   15   2  0.079  0.238  0.089
# 29         Amed Rosario  165  170   4   16   10   7  0.018  0.288  0.145
# ..                  ...  ...  ...  ..  ...  ...  ..    ...    ...    ...
# 426            Ty Kelly   89  105   2   11   14   0  0.076  0.238  0.146
# 427       Tyler Collins  150  169   5   18   14   0  0.107  0.325  0.140
# 428       Tyler Flowers  317  370  12   41   49   0  0.084  0.222  0.164
# 429         Tyler Moore  187  203   6   17   30   0  0.049  0.276  0.171
# 430      Tyler Saladino  253  281   0   23   10   5  0.082  0.238  0.051
# 431     Victor Martinez  392  435  10   38   47   0  0.083  0.145  0.117
# 432  Welington Castillo  341  365  20   44   53   0  0.060  0.266  0.208
# 433     Whit Merrifield  587  630  19   80   78  34  0.046  0.140  0.172
# 434           Wil Myers  567  649  30   80   74  20  0.108  0.277  0.220
# 435   Willson Contreras  377  428  21   50   74   5  0.105  0.229  0.223
# 436        Willy Garcia  105  119   2   15   12   0  0.092  0.261  0.162
# 437         Wilmer Difo  332  365   5   47   21  10  0.066  0.203  0.099
# 438       Wilmer Flores  336  362  18   42   52   1  0.047  0.149  0.217
# 439        Wilson Ramos  208  224  11   19   35   0  0.045  0.161  0.188
# 440     Xander Bogaerts  571  635  10   94   62  15  0.088  0.183  0.130
# 441       Yadier Molina  501  543  18   60   82   9  0.052  0.136  0.166
# 442           Yan Gomes  341  383  14   43   56   0  0.081  0.258  0.167
# 443          Yandy Diaz  156  179   0   25   13   2  0.117  0.196  0.064
# 444   Yangervis Solarte  466  512  18   49   64   3  0.072  0.119  0.161
# 445         Yasiel Puig  499  570  28   72   74  15  0.112  0.175  0.224
# 446     Yasmani Grandal  438  482  22   50   58   0  0.083  0.270  0.212
# 447       Yasmany Tomas  166  180   8   19   32   0  0.072  0.278  0.223
# 448        Yoan Moncada  199  231   8   31   22   3  0.126  0.320  0.181
# 449     Yoenis Cespedes  291  321  17   46   42   0  0.081  0.190  0.247
# 450      Yolmer Sanchez  484  534  12   63   59   8  0.066  0.208  0.147
# 451       Yonder Alonso  451  521  28   72   67   2  0.131  0.226  0.235
# 452        Yuli Gurriel  529  564  18   69   75   3  0.039  0.110  0.187
# 453       Yunel Escobar  350  381   7   43   31   1  0.076  0.134  0.123
# 454         Zack Cozart  438  507  24   80   63   3  0.122  0.154  0.251
# 455        Zack Granite   93  107   1   14   13   2  0.112  0.084  0.054
#
#      BABIP    AVG    OBP    SLG   wOBA  wRC+  WAR
# 0    0.222  0.210  0.298  0.371  0.294    80  0.2
# 1    0.291  0.266  0.330  0.471  0.340   103  2.1
# 2    0.328  0.272  0.340  0.516  0.359   120  1.3
# 3    0.290  0.266  0.372  0.475  0.363   127  3.3
# 4    0.357  0.284  0.422  0.627  0.430   173  8.2
# 5    0.298  0.233  0.314  0.366  0.298    81 -0.1
# 6    0.290  0.249  0.301  0.480  0.327    98  1.8
# 7    0.347  0.297  0.393  0.462  0.369   126  0.5
# 8    0.247  0.166  0.235  0.282  0.230    37 -0.7
# 9    0.306  0.276  0.344  0.399  0.322    97  1.1
# 10   0.312  0.285  0.322  0.466  0.334   107  1.7
# 11   0.316  0.303  0.362  0.513  0.363   122  0.9
# 12   0.312  0.225  0.260  0.353  0.261    57 -0.5
# 13   0.289  0.239  0.304  0.418  0.305    84  1.4
# 14   0.304  0.261  0.289  0.406  0.295    83  1.3
# 15   0.247  0.237  0.273  0.347  0.269    61 -0.4
# 16   0.321  0.312  0.383  0.532  0.384   138  3.1
# 17   0.280  0.242  0.287  0.355  0.275    69 -1.1
# 18   0.338  0.298  0.338  0.445  0.334   103  1.2
# 19   0.249  0.241  0.286  0.386  0.286    78 -2.0
# 20   0.291  0.250  0.272  0.357  0.269    62  0.5
# 21   0.282  0.259  0.290  0.392  0.291    78  0.2
# 22   0.268  0.221  0.262  0.346  0.261    59 -0.8
# 23   0.382  0.264  0.387  0.447  0.362   124  2.5
# 24   0.311  0.284  0.352  0.475  0.351   122  3.8
# 25   0.261  0.208  0.293  0.315  0.269    62  0.0
# 26   0.383  0.314  0.354  0.416  0.334   106  0.5
# 27   0.291  0.238  0.269  0.351  0.267    45 -1.2
# 28   0.259  0.208  0.282  0.297  0.256    57 -1.1
# 29   0.330  0.248  0.271  0.394  0.282    74  0.3
# ..     ...    ...    ...    ...    ...   ...  ...
# 426  0.231  0.191  0.257  0.337  0.256    53 -0.2
# 427  0.264  0.193  0.278  0.333  0.269    62 -0.2
# 428  0.342  0.281  0.378  0.445  0.358   120  2.5
# 429  0.287  0.230  0.267  0.401  0.282    72 -0.2
# 430  0.242  0.178  0.254  0.229  0.223    33 -1.2
# 431  0.280  0.255  0.324  0.372  0.303    85 -1.1
# 432  0.336  0.282  0.323  0.490  0.344   113  2.7
# 433  0.308  0.288  0.324  0.460  0.332   105  3.1
# 434  0.297  0.243  0.328  0.464  0.335   109  0.9
# 435  0.319  0.276  0.356  0.499  0.362   121  3.2
# 436  0.311  0.238  0.305  0.400  0.301    86  0.0
# 437  0.332  0.271  0.319  0.370  0.293    76  1.0
# 438  0.270  0.271  0.307  0.488  0.331   106  0.9
# 439  0.262  0.260  0.290  0.447  0.307    92  0.4
# 440  0.327  0.273  0.343  0.403  0.321    96  3.2
# 441  0.285  0.273  0.312  0.439  0.316    94  2.1
# 442  0.283  0.232  0.309  0.399  0.307    87  1.8
# 443  0.336  0.263  0.352  0.327  0.306    86  0.5
# 444  0.258  0.255  0.314  0.416  0.311    93  1.1
# 445  0.274  0.263  0.346  0.487  0.349   117  2.9
# 446  0.298  0.247  0.308  0.459  0.325   102  2.5
# 447  0.294  0.241  0.294  0.464  0.319    89  0.1
# 448  0.325  0.231  0.338  0.412  0.327   104  0.9
# 449  0.316  0.292  0.352  0.540  0.369   131  1.6
# 450  0.321  0.267  0.319  0.413  0.313    94  2.1
# 451  0.302  0.266  0.365  0.501  0.366   132  2.4
# 452  0.308  0.299  0.332  0.486  0.344   118  1.8
# 453  0.305  0.274  0.333  0.397  0.318   100  0.8
# 454  0.312  0.297  0.385  0.548  0.392   141  5.0
# 455  0.250  0.237  0.321  0.290  0.278    67 -0.2
#
# [456 rows x 17 columns]

# %%
# two player names columns after merging (short/full name differences) and player_id is now our index so we'll drop that too
merged_2015.drop(['player_name_y', 'player_id'], axis=1, inplace=True)
merged_2016.drop(['player_name_y', 'player_id'], axis=1, inplace=True)
merged_2017.drop(['player_name_y', 'player_id'], axis=1, inplace=True)

# %%
# check in to see what our merged data looks like
merged_2015.info()
print("-------------------------------------")
merged_2016.info()
print("-------------------------------------")
merged_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 467 entries, 0 to 466
# Data columns (total 25 columns):
# player_name_x    467 non-null object
# AB               467 non-null int64
# PA               467 non-null int64
# HR               467 non-null int64
# R                467 non-null int64
# RBI              467 non-null int64
# SB               467 non-null int64
# BB%              467 non-null float64
# K%               467 non-null float64
# ISO              467 non-null float64
# BABIP            467 non-null float64
# AVG              467 non-null float64
# OBP              467 non-null float64
# SLG              467 non-null float64
# wOBA             467 non-null float64
# wRC+             467 non-null int64
# WAR              467 non-null float64
# xwoba            467 non-null float64
# xba              467 non-null float64
# hits             467 non-null int64
# launch_speed     467 non-null float64
# launch_angle     467 non-null float64
# whiffs           467 non-null int64
# swings           467 non-null int64
# takes            467 non-null int64
# dtypes: float64(13), int64(11), object(1)
# memory usage: 91.3+ KB
# -------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 459 entries, 0 to 458
# Data columns (total 25 columns):
# player_name_x    459 non-null object
# AB               459 non-null int64
# PA               459 non-null int64
# HR               459 non-null int64
# R                459 non-null int64
# RBI              459 non-null int64
# SB               459 non-null int64
# BB%              459 non-null float64
# K%               459 non-null float64
# ISO              459 non-null float64
# BABIP            459 non-null float64
# AVG              459 non-null float64
# OBP              459 non-null float64
# SLG              459 non-null float64
# wOBA             459 non-null float64
# wRC+             459 non-null int64
# WAR              459 non-null float64
# xwoba            459 non-null float64
# xba              459 non-null float64
# hits             459 non-null int64
# launch_speed     459 non-null float64
# launch_angle     459 non-null float64
# whiffs           459 non-null int64
# swings           459 non-null int64
# takes            459 non-null int64
# dtypes: float64(13), int64(11), object(1)
# memory usage: 89.7+ KB
# -------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 25 columns):
# player_name_x    456 non-null object
# AB               456 non-null int64
# PA               456 non-null int64
# HR               456 non-null int64
# R                456 non-null int64
# RBI              456 non-null int64
# SB               456 non-null int64
# BB%              456 non-null float64
# K%               456 non-null float64
# ISO              456 non-null float64
# BABIP            456 non-null float64
# AVG              456 non-null float64
# OBP              456 non-null float64
# SLG              456 non-null float64
# wOBA             456 non-null float64
# wRC+             456 non-null int64
# WAR              456 non-null float64
# xwoba            456 non-null float64
# xba              456 non-null float64
# hits             456 non-null int64
# launch_speed     456 non-null float64
# launch_angle     456 non-null float64
# whiffs           456 non-null int64
# swings           456 non-null int64
# takes            456 non-null int64
# dtypes: float64(13), int64(11), object(1)
# memory usage: 89.1+ KB

# %%
# making all column names consistent for readability moving forward
merged_2015.rename(columns={'player_name_x':'Player_Name', 'AVG':'BA', 'pitches':'Pitches', 'BB%':'BB/PA', 'K%':'K/PA',
                            'iso':'ISO', 'babip':'BABIP', 'slg':'SLG', 'woba':'wOBA', 'xwoba':'xwOBA', 'xba':'xBA', 
                            'hits':'Hits', 'launch_speed':'Launch_Speed', 'launch_angle':'Launch_Angle', 'whiffs':'Whiffs', 
                            'swings':'Swings', 'takes':'Takes'}, inplace=True)
merged_2016.rename(columns={'player_name_x':'Player_Name', 'AVG':'BA', 'pitches':'Pitches', 'BB%':'BB/PA', 'K%':'K/PA',
                            'iso':'ISO', 'babip':'BABIP', 'slg':'SLG', 'woba':'wOBA', 'xwoba':'xwOBA', 'xba':'xBA', 
                            'hits':'Hits', 'launch_speed':'Launch_Speed', 'launch_angle':'Launch_Angle', 'whiffs':'Whiffs', 
                            'swings':'Swings', 'takes':'Takes'}, inplace=True)
merged_2017.rename(columns={'player_name_x':'Player_Name', 'AVG':'BA', 'pitches':'Pitches', 'BB%':'BB/PA', 'K%':'K/PA',
                            'iso':'ISO', 'babip':'BABIP', 'slg':'SLG', 'woba':'wOBA', 'xwoba':'xwOBA', 'xba':'xBA', 
                            'hits':'Hits', 'launch_speed':'Launch_Speed', 'launch_angle':'Launch_Angle', 'whiffs':'Whiffs', 
                            'swings':'Swings', 'takes':'Takes'}, inplace=True)

# %%
# reorder columns for more logical ordering
merged_2015 = merged_2015[['Player_Name', 'PA', 'AB', 'Hits', 'R', 'HR', 'RBI', 
                           'SB', 'BA', 'xBA', 'OBP', 'BABIP', 'ISO', 'SLG', 'wOBA', 'xwOBA', 
                           'BB/PA', 'K/PA', 'Launch_Speed', 'Launch_Angle', 'Whiffs', 
                           'Swings', 'Takes', 'wRC+', 'WAR']]
merged_2016 = merged_2016[['Player_Name', 'PA', 'AB', 'Hits', 'R', 'HR', 'RBI', 
                           'SB', 'BA', 'xBA', 'OBP', 'BABIP', 'ISO', 'SLG', 'wOBA', 'xwOBA', 
                           'BB/PA', 'K/PA', 'Launch_Speed', 'Launch_Angle', 'Whiffs', 
                           'Swings', 'Takes', 'wRC+', 'WAR']]
merged_2017 = merged_2017[['Player_Name', 'PA', 'AB', 'Hits', 'R', 'HR', 'RBI', 
                           'SB', 'BA', 'xBA', 'OBP', 'BABIP', 'ISO', 'SLG', 'wOBA', 'xwOBA', 
                           'BB/PA', 'K/PA', 'Launch_Speed', 'Launch_Angle', 'Whiffs', 
                           'Swings', 'Takes', 'wRC+', 'WAR']]

# %%
# save merged files as csv for further analysis
merged_2015.to_csv("C:/Users/avitosky/Documents/Baseball Project/merged_2015.csv")
merged_2016.to_csv("C:/Users/avitosky/Documents/Baseball Project/merged_2016.csv")
merged_2017.to_csv("C:/Users/avitosky/Documents/Baseball Project/merged_2017.csv")
